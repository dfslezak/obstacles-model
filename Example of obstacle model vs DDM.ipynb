# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
sb.set()

import sim
import simMaze

# %% [markdown]
# # DDM with threshold distance = 5

# %%
res = sim.oneSim(p=0.5,NSIMS=30000)

# %%
THRES_DIST = 5
hh,bins = np.histogram(res[THRES_DIST,:],bins=50,normed=True)
plt.semilogy(bins[:-1],hh)

# %% [markdown]
# # Obstacles model with threshold distance = 5

# %%
resMaze = simMaze.oneSimMaze(obstacles=0.5,NSIMS=30000)

# %%
THRES_DIST = 5
hhMaze,binsMaze = np.histogram(resMaze[THRES_DIST,:],bins=bins,normed=True)
plt.semilogy(binsMaze[:-1],hhMaze)
